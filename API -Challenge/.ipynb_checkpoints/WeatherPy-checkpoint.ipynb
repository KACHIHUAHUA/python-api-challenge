# %% [markdown]
# WeatherPy
# ----
# archivo de trabajo al 9 d efeb de 2021
# Note
# Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you
# think through the steps.
#
# Observable trends:
#
# 1.- Most of the selected cities are in the northern hemisphere, because in this one, most of the habitable land of the
# planet is found.
#
# 2.- Given the above, in the northern hemisphere is where it is possible to find cities that have the lowest maximum
# temperatures.
#
# 3.- Factors such as humidity, wind speed and cloudiness are not greatly affected by latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import itertools as it
from scipy import stats


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
#cities
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#look for the weather of each city in cities

#config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
key = weather_api_key

#partial query
query_url = f"{url}appid={key}&units={units}&q="

#create the structure of the dataframe
ciudad = []
lat = []
lon = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

#cities = ["rikitea", "georgetown", "tallahassee"]

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    #print(response)
    
    try:
        id = response['id']
        ciudad.append(response["name"])
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        print (f"The city {city} with ID: {id} is being processed")
        
    except (KeyError, IndexError):    
        print(f"{city} missing field/result, keep going!")
# Out:
# The city xining with ID: 1788852 is being processed
# The city bridlington with ID: 2654728 is being processed
# The city kidal with ID: 2455290 is being processed
# The city pevek with ID: 2122090 is being processed
# The city rikitea with ID: 4030556 is being processed
# The city albany with ID: 5106841 is being processed
# The city barrow with ID: 5880054 is being processed
# The city provideniya with ID: 4031574 is being processed
# The city ribeira grande with ID: 3372707 is being processed
# The city butaritari with ID: 2110227 is being processed
# The city katangli with ID: 2122783 is being processed
# louisbourg missing field/result, keep going!
# attawapiskat missing field/result, keep going!
# The city bluff with ID: 2206939 is being processed
# burica missing field/result, keep going!
# The city piura with ID: 3693528 is being processed
# taolanaro missing field/result, keep going!
# The city ushuaia with ID: 3833367 is being processed
# The city bacungan with ID: 1729456 is being processed
# The city santa maria with ID: 3450083 is being processed
# The city lebu with ID: 3883457 is being processed
# The city tutoia with ID: 3385899 is being processed
# The city chapeco with ID: 3466296 is being processed
# The city jamestown with ID: 5122534 is being processed
# The city yining with ID: 1786538 is being processed
# The city coquimbo with ID: 3893629 is being processed
# The city oranjestad with ID: 3577154 is being processed
# The city buala with ID: 2109528 is being processed
# The city busselton with ID: 2075265 is being processed
# The city wajima with ID: 1848976 is being processed
# The city luanda with ID: 2240449 is being processed
# The city hilo with ID: 5855927 is being processed
# The city yellowknife with ID: 6185377 is being processed
# The city acapulco with ID: 3533462 is being processed
# The city sibolga with ID: 1213855 is being processed
# The city moramanga with ID: 1058532 is being processed
# The city puerto ayora with ID: 3652764 is being processed
# The city clarence town with ID: 2171465 is being processed
# The city manavalakurichi with ID: 1263942 is being processed
# The city avarua with ID: 4035715 is being processed
# The city krasnoarmeysk with ID: 542464 is being processed
# The city mahebourg with ID: 934322 is being processed
# The city atuona with ID: 4020109 is being processed
# The city el reno with ID: 4535783 is being processed
# The city hobart with ID: 2163355 is being processed
# The city new norfolk with ID: 2155415 is being processed
# The city arraial do cabo with ID: 3471451 is being processed
# The city mataura with ID: 6201424 is being processed
# The city qom with ID: 119208 is being processed
# The city christchurch with ID: 2192362 is being processed
# The city manono with ID: 209598 is being processed
# The city castro with ID: 3466704 is being processed
# The city vaini with ID: 4032243 is being processed
# The city brae with ID: 2654970 is being processed
# The city hermanus with ID: 3366880 is being processed
# nizhneyansk missing field/result, keep going!
# The city hasaki with ID: 2112802 is being processed
# The city saskylakh with ID: 2017155 is being processed
# The city dikson with ID: 1507390 is being processed
# The city linhares with ID: 3458498 is being processed
# The city manta with ID: 3654410 is being processed
# The city caravelas with ID: 3466980 is being processed
# The city dolores with ID: 3435038 is being processed
# kerteh missing field/result, keep going!
# The city puerto escondido with ID: 3520994 is being processed
# mizpe ramon missing field/result, keep going!
# The city krutinka with ID: 1501690 is being processed
# ruatoria missing field/result, keep going!
# The city buchanan with ID: 2278158 is being processed
# The city georgetown with ID: 1735106 is being processed
# The city hithadhoo with ID: 1282256 is being processed
# The city bossangoa with ID: 2388036 is being processed
# tsihombe missing field/result, keep going!
# The city nanortalik with ID: 3421765 is being processed
# The city bayanday with ID: 2027004 is being processed
# The city zabid with ID: 69500 is being processed
# The city presidencia roque saenz pena with ID: 3840300 is being processed
# The city vila with ID: 7117100 is being processed
# The city muravlenko with ID: 1540711 is being processed
# The city vila velha with ID: 3445026 is being processed
# The city verkhnyaya inta with ID: 1487332 is being processed
# The city longhua with ID: 1802618 is being processed
# The city adrar with ID: 2381972 is being processed
# bac can missing field/result, keep going!
# The city avera with ID: 4231997 is being processed
# The city phuket with ID: 1151253 is being processed
# The city tuatapere with ID: 2180815 is being processed
# The city punta arenas with ID: 3874787 is being processed
# The city deputatskiy with ID: 2028164 is being processed
# The city carnarvon with ID: 2074865 is being processed
# The city ust-nera with ID: 2120048 is being processed
# The city airai with ID: 1651810 is being processed
# afmadu missing field/result, keep going!
# The city saint george with ID: 5546220 is being processed
# The city kaitangata with ID: 2208248 is being processed
# The city ponta do sol with ID: 2264557 is being processed
# The city laguna with ID: 5364271 is being processed
# The city alofi with ID: 4036284 is being processed
# The city atar with ID: 2381334 is being processed
# The city victoria with ID: 1819729 is being processed
# The city belmonte with ID: 3470137 is being processed
# The city freeport with ID: 5117949 is being processed
# illoqqortoormiut missing field/result, keep going!
# The city kon tum with ID: 1578500 is being processed
# The city poum with ID: 2138555 is being processed
# The city dunedin with ID: 2191562 is being processed
# The city lompoc with ID: 5367788 is being processed
# The city cape town with ID: 3369157 is being processed
# The city ilulissat with ID: 3423146 is being processed
# The city ahuimanu with ID: 5856516 is being processed
# The city kapaa with ID: 5848280 is being processed
# The city bredasdorp with ID: 1015776 is being processed
# The city dukat with ID: 2125906 is being processed
# The city port-gentil with ID: 2396518 is being processed
# The city stolbishche with ID: 487444 is being processed
# The city tonantins with ID: 3661894 is being processed
# The city grindavik with ID: 3416888 is being processed
# The city cabo san lucas with ID: 3985710 is being processed
# The city nuqui with ID: 3673690 is being processed
# The city saint-pierre with ID: 935214 is being processed
# The city roma with ID: 5134295 is being processed
# The city tiarei with ID: 4033356 is being processed
# The city bathsheba with ID: 3374083 is being processed
# sentyabrskiy missing field/result, keep going!
# The city rockland with ID: 5134189 is being processed
# The city norman wells with ID: 6089245 is being processed
# The city constitucion with ID: 3893726 is being processed
# The city srednekolymsk with ID: 2121025 is being processed
# The city kloulklubed with ID: 7671223 is being processed
# The city ancud with ID: 3899695 is being processed
# The city quelimane with ID: 1028434 is being processed
# The city kautokeino with ID: 779330 is being processed
# The city sioux lookout with ID: 6148373 is being processed
# The city juybar with ID: 129933 is being processed
# The city talaya with ID: 2120769 is being processed
# The city port alfred with ID: 964432 is being processed
# The city palmeira with ID: 3455425 is being processed
# The city kodiak with ID: 5866583 is being processed
# The city ewa beach with ID: 5855051 is being processed
# The city mount isa with ID: 2065594 is being processed
# zhanatas missing field/result, keep going!
# The city faanui with ID: 4034551 is being processed
# The city brigantine with ID: 4500920 is being processed
# The city iqaluit with ID: 5983720 is being processed
# The city kruisfontein with ID: 986717 is being processed
# The city thayetmyo with ID: 1292037 is being processed
# The city atbasar with ID: 1526038 is being processed
# The city lasa with ID: 3175096 is being processed
# The city east london with ID: 1006984 is being processed
# The city pimentel with ID: 3693584 is being processed
# The city khatanga with ID: 2022572 is being processed
# The city olga with ID: 2018553 is being processed
# The city klaksvik with ID: 2618795 is being processed
# The city aranos with ID: 3358666 is being processed
# The city gold coast with ID: 2165087 is being processed
# The city tura with ID: 1254046 is being processed
# The city souillac with ID: 933995 is being processed
# belushya guba missing field/result, keep going!
# The city kayseri with ID: 308463 is being processed
# The city terrace bay with ID: 6162951 is being processed
# The city mar del plata with ID: 3430863 is being processed
# The city qui nhon with ID: 1568574 is being processed
# The city liwale with ID: 155921 is being processed
# marcona missing field/result, keep going!
# The city turan with ID: 1583992 is being processed
# The city maragogi with ID: 3395458 is being processed
# The city huanan with ID: 2036753 is being processed
# The city itaperuna with ID: 3460733 is being processed
# The city feijo with ID: 3664243 is being processed
# The city tottori with ID: 1849892 is being processed
# The city hong gai with ID: 1580410 is being processed
# The city kilindoni with ID: 157429 is being processed
# The city dannenberg with ID: 2938991 is being processed
# The city qaanaaq with ID: 3831208 is being processed
# tabiauea missing field/result, keep going!
# chagda missing field/result, keep going!
# The city halifax with ID: 6324729 is being processed
# The city baloda bazar with ID: 1277530 is being processed
# The city katobu with ID: 1640972 is being processed
# The city general roca with ID: 3855065 is being processed
# The city homer with ID: 5864145 is being processed
# The city tiksi with ID: 2015306 is being processed
# The city ayagoz with ID: 1525988 is being processed
# grand river south east missing field/result, keep going!
# The city cabedelo with ID: 3404558 is being processed
# The city yumen with ID: 1528998 is being processed
# The city talcahuano with ID: 3870282 is being processed
# The city tuktoyaktuk with ID: 6170031 is being processed
# The city pudozh with ID: 504269 is being processed
# The city aitape with ID: 2101169 is being processed
# The city carballo with ID: 3126369 is being processed
# The city kashi with ID: 1280849 is being processed
# The city tasiilaq with ID: 3424607 is being processed
# The city praya with ID: 3374333 is being processed
# The city banda aceh with ID: 1215502 is being processed
# The city chicama with ID: 3698359 is being processed
# The city saurimo with ID: 145531 is being processed
# The city sur with ID: 286245 is being processed
# The city ihosy with ID: 1064275 is being processed
# The city nago with ID: 1856068 is being processed
# The city thompson with ID: 6165406 is being processed
# The city marawi with ID: 1701054 is being processed
# The city port hardy with ID: 6111862 is being processed
# The city nanning with ID: 1799869 is being processed
# The city champerico with ID: 3598787 is being processed
# The city lerwick with ID: 2644605 is being processed
# amderma missing field/result, keep going!
# The city puerto colombia with ID: 3671497 is being processed
# The city kununurra with ID: 2068110 is being processed
# The city dabat with ID: 340358 is being processed
# The city kismayo with ID: 55671 is being processed
# mys shmidta missing field/result, keep going!
# The city puerto penasco with ID: 3991347 is being processed
# The city cap malheureux with ID: 934649 is being processed
# The city ketchikan with ID: 5554428 is being processed
# The city usogorsk with ID: 478297 is being processed
# The city nikolskoye with ID: 546105 is being processed
# The city eckernforde with ID: 2933627 is being processed
# The city geraldton with ID: 2070998 is being processed
# The city luorong with ID: 1801850 is being processed
# The city san policarpo with ID: 1688696 is being processed
# The city karachev with ID: 552920 is being processed
# The city san cristobal with ID: 3628473 is being processed
# The city birao with ID: 240210 is being processed
# The city moberly with ID: 4398730 is being processed
# barawe missing field/result, keep going!
# karaul missing field/result, keep going!
# barentsburg missing field/result, keep going!
# The city yulara with ID: 6355222 is being processed
# The city saldanha with ID: 3361934 is being processed
# The city havre-saint-pierre with ID: 5972291 is being processed
# The city merauke with ID: 2082539 is being processed
# The city kalangala with ID: 232571 is being processed
# The city lima with ID: 3936456 is being processed
# The city nouadhibou with ID: 2377457 is being processed
# The city lagoa with ID: 3372964 is being processed
# The city kokkola with ID: 651943 is being processed
# The city ningyang with ID: 1799348 is being processed
# The city ngunguru with ID: 2186111 is being processed
# The city severo-kurilsk with ID: 2121385 is being processed
# The city boa vista with ID: 3664980 is being processed
# The city areka with ID: 343593 is being processed
# The city san quintin with ID: 3984997 is being processed
# The city longyearbyen with ID: 2729907 is being processed
# The city ayni with ID: 1222222 is being processed
# The city namibe with ID: 3347019 is being processed
# The city kuybyshevo with ID: 538061 is being processed
# The city bangsund with ID: 3145023 is being processed
# The city torbay with ID: 6167817 is being processed
# The city yarkovo with ID: 1486369 is being processed
# The city monte carmelo with ID: 3456848 is being processed
# The city shimoda with ID: 1852357 is being processed
# The city chuy with ID: 3443061 is being processed
# The city dingzhou with ID: 1812728 is being processed
# kachikau missing field/result, keep going!
# The city kyaikto with ID: 1317375 is being processed
# The city richards bay with ID: 962367 is being processed
# The city beringovskiy with ID: 2126710 is being processed
# vaitupu missing field/result, keep going!
# The city upernavik with ID: 3418910 is being processed
# The city laki with ID: 729509 is being processed
# The city jiexiu with ID: 1805833 is being processed
# The city hervey bay with ID: 2146219 is being processed
# The city sao sebastiao with ID: 3448257 is being processed
# The city saint-philippe with ID: 935215 is being processed
# The city la ronge with ID: 6050066 is being processed
# The city fortuna with ID: 5563839 is being processed
# The city saint-francois with ID: 2980080 is being processed
# The city tucuman with ID: 3836873 is being processed
# The city vao with ID: 2137773 is being processed
# The city biltine with ID: 244878 is being processed
# The city lencois paulista with ID: 3458645 is being processed
# The city half moon bay with ID: 5354943 is being processed
# The city alta floresta with ID: 6316343 is being processed
# The city sao filipe with ID: 3374210 is being processed
# The city cherskiy with ID: 2126199 is being processed
# The city bethel with ID: 5282297 is being processed
# The city denpasar with ID: 1645528 is being processed
# The city mackay with ID: 2159220 is being processed
# The city manaure with ID: 3675504 is being processed
# The city mount gambier with ID: 2156643 is being processed
# The city krasnoselkup with ID: 1502073 is being processed
# The city basar with ID: 1276788 is being processed
# The city santa barbara with ID: 5392967 is being processed
# The city along with ID: 1278969 is being processed
# sapao missing field/result, keep going!
# The city unguia with ID: 3666475 is being processed
# The city mut with ID: 304013 is being processed
# The city bhikangaon with ID: 1275978 is being processed
# The city praia da vitoria with ID: 3372760 is being processed
# samusu missing field/result, keep going!
# The city ugoofaaru with ID: 1337619 is being processed
# The city karratha with ID: 6620339 is being processed
# The city berlevag with ID: 780687 is being processed
# The city meulaboh with ID: 1214488 is being processed
# The city jasper with ID: 4392354 is being processed
# bargal missing field/result, keep going!
# The city palu with ID: 1633034 is being processed
# The city sao joao da barra with ID: 3448903 is being processed
# The city college with ID: 5859699 is being processed
# The city sorland with ID: 3137469 is being processed
# The city kharan with ID: 1174062 is being processed
# The city bone with ID: 2937959 is being processed
# The city maridi with ID: 370457 is being processed
# The city tarakan with ID: 1624725 is being processed
# The city luderitz with ID: 3355672 is being processed
# The city hirara with ID: 1862505 is being processed
# The city kahului with ID: 5847411 is being processed
# The city cayenne with ID: 3382160 is being processed
# The city broken hill with ID: 2173911 is being processed
# The city bella union with ID: 3443631 is being processed
# The city wanning with ID: 1791779 is being processed
# The city nybro with ID: 2687902 is being processed
# The city hopeman with ID: 2646630 is being processed
# The city saint-georges with ID: 3579925 is being processed
# The city carora with ID: 3646487 is being processed
# The city parkersburg with ID: 4817641 is being processed
# The city thinadhoo with ID: 1337610 is being processed
# The city palmer with ID: 4946620 is being processed
# The city campos do jordao with ID: 3467684 is being processed
# The city kasungu with ID: 928534 is being processed
# The city haapiti with ID: 4034438 is being processed
# The city ende with ID: 1644932 is being processed
# grand centre missing field/result, keep going!
# The city mitsamiouli with ID: 921786 is being processed
# The city dubovka with ID: 564654 is being processed
# The city ucluelet with ID: 6171633 is being processed
# The city yeppoon with ID: 2142316 is being processed
# The city vila franca do campo with ID: 3372472 is being processed
# The city moron with ID: 3430545 is being processed
# The city port elizabeth with ID: 964420 is being processed
# The city cidreira with ID: 3466165 is being processed
# samalaeulu missing field/result, keep going!
# The city the valley with ID: 3573374 is being processed
# The city touros with ID: 3386213 is being processed
# The city oyon with ID: 3933867 is being processed
# The city chokurdakh with ID: 2126123 is being processed
# satitoa missing field/result, keep going!
# The city nahan with ID: 1262151 is being processed
# The city mangaratiba with ID: 3457991 is being processed
# The city vostok with ID: 2013279 is being processed
# The city biri with ID: 1724803 is being processed
# The city san patricio with ID: 4726521 is being processed
# The city mwinilunga with ID: 902620 is being processed
# The city la romana with ID: 3500957 is being processed
# The city sinnamary with ID: 3380290 is being processed
# The city taoudenni with ID: 2450173 is being processed
# The city winfield with ID: 4281897 is being processed
# The city tolaga bay with ID: 2180991 is being processed
# The city kuytun with ID: 2021093 is being processed
# The city hofn with ID: 2630299 is being processed
# The city buraydah with ID: 107304 is being processed
# The city svetlogorsk with ID: 10722858 is being processed
# The city ballina with ID: 2177069 is being processed
# The city gohad with ID: 1271083 is being processed
# The city gloversville with ID: 5118743 is being processed
# The city puerto carreno with ID: 3671519 is being processed
# The city san jose with ID: 5392171 is being processed
# The city sabang with ID: 1214026 is being processed
# The city olinda with ID: 3393536 is being processed
# The city dhenkanal with ID: 1272780 is being processed
# The city morondava with ID: 1058381 is being processed
# The city acajutla with ID: 3587498 is being processed
# The city portland with ID: 5746545 is being processed
# The city severnyy with ID: 496358 is being processed
# The city sawakin with ID: 367544 is being processed
# The city twin falls with ID: 5610815 is being processed
# The city nome with ID: 5870133 is being processed
# The city harper with ID: 2276492 is being processed
# The city sao gabriel da cachoeira with ID: 3662342 is being processed
# The city gerash with ID: 133595 is being processed
# The city ulaanbaatar with ID: 2028462 is being processed
# The city cap-aux-meules with ID: 5915327 is being processed
# The city vung tau with ID: 1562414 is being processed
# The city sarishabari with ID: 1188569 is being processed
# The city paamiut with ID: 3421193 is being processed
# The city ixtapa with ID: 4004293 is being processed
# The city namtsy with ID: 2019488 is being processed
# The city ivanivka with ID: 707453 is being processed
# The city caohai with ID: 1816028 is being processed
# The city comodoro rivadavia with ID: 3860443 is being processed
# The city nsanje with ID: 924572 is being processed
# The city tucurui with ID: 3385935 is being processed
# The city lewisville with ID: 4706057 is being processed
# The city ola with ID: 2122574 is being processed
# ijaki missing field/result, keep going!
# The city tomatlan with ID: 3981391 is being processed
# The city trindade with ID: 3446038 is being processed
# The city gat with ID: 293842 is being processed
# The city sorong with ID: 1626542 is being processed
# The city florianopolis with ID: 6323121 is being processed
# dzhusaly missing field/result, keep going!
# The city ostrovnoy with ID: 556268 is being processed
# The city kindu with ID: 212902 is being processed
# The city zhigansk with ID: 2012530 is being processed
# The city vanimo with ID: 2084442 is being processed
# The city bubaque with ID: 2374583 is being processed
# duz missing field/result, keep going!
# The city leningradskiy with ID: 2123814 is being processed
# The city kano with ID: 2335204 is being processed
# The city qasigiannguit with ID: 3420768 is being processed
# The city te anau with ID: 2181625 is being processed
# ngukurr missing field/result, keep going!
# The city saint anthony with ID: 5044290 is being processed
# The city walvis bay with ID: 3359638 is being processed
# The city bintulu with ID: 1737486 is being processed
# The city xingyi with ID: 1787599 is being processed
# The city harbour breton with ID: 5970478 is being processed
# The city altay with ID: 1529651 is being processed
# The city lavrentiya with ID: 4031637 is being processed
# The city qaqortoq with ID: 3420846 is being processed
# The city dingle with ID: 1714733 is being processed
# The city padang with ID: 1633419 is being processed
# The city vaitape with ID: 4033077 is being processed
# The city shakawe with ID: 933077 is being processed
# The city menongue with ID: 3347353 is being processed
# The city lere with ID: 2332079 is being processed
# The city bristol with ID: 4931378 is being processed
# The city korla with ID: 1529376 is being processed
# The city faya with ID: 110690 is being processed
# The city manokwari with ID: 1636308 is being processed
# The city rognan with ID: 3141548 is being processed
# The city naze with ID: 1855540 is being processed
# The city houma with ID: 4328010 is being processed
# The city tsumeb with ID: 3352593 is being processed
# The city roebourne with ID: 2062276 is being processed
# The city saint-joseph with ID: 6690296 is being processed
# The city barabai with ID: 1650064 is being processed
# The city matadi with ID: 2313002 is being processed
# The city bama with ID: 2347954 is being processed
# The city bengkulu with ID: 1649150 is being processed
# The city rudbar with ID: 1128239 is being processed
# The city orje with ID: 3143427 is being processed
# The city lumeje with ID: 876123 is being processed
# The city huarmey with ID: 3939168 is being processed
# The city antibes with ID: 3037456 is being processed
# The city plettenberg bay with ID: 964712 is being processed
# The city ereymentau with ID: 1524302 is being processed
# The city yuxia with ID: 1785572 is being processed
# The city seymchan with ID: 2121373 is being processed
# The city aklavik with ID: 5882953 is being processed
# The city peniche with ID: 2264923 is being processed
# The city les cayes with ID: 3728097 is being processed
# The city boguchany with ID: 1509844 is being processed
# asayita missing field/result, keep going!
# The city isangel with ID: 2136825 is being processed
# The city alice springs with ID: 2077895 is being processed
# The city salalah with ID: 286621 is being processed
# The city manoel urbano with ID: 3663495 is being processed
# The city hay river with ID: 5972762 is being processed
# The city mayumba with ID: 2399001 is being processed
# The city clyde river with ID: 5924351 is being processed
# The city beira with ID: 1052373 is being processed
# The city lagunas with ID: 3695844 is being processed
# The city bambous virieux with ID: 1106677 is being processed
# The city burnie with ID: 2173125 is being processed
# The city urumqi with ID: 1529102 is being processed
# The city bontang with ID: 1648186 is being processed
# The city road town with ID: 3577430 is being processed
# The city micheweni with ID: 153955 is being processed
# The city ahipara with ID: 2194098 is being processed
# The city warrnambool with ID: 2144528 is being processed
# tumannyy missing field/result, keep going!
# The city bahar with ID: 142000 is being processed
# The city macklin with ID: 6063429 is being processed
# The city poggibonsi with ID: 3170504 is being processed
# The city mtinko with ID: 152781 is being processed
# The city santa elena with ID: 3651438 is being processed
# The city zatoka with ID: 687557 is being processed
# The city natal with ID: 3394023 is being processed
# The city kochevo with ID: 546845 is being processed
# The city maniitsoq with ID: 3421982 is being processed
# The city prince george with ID: 6113365 is being processed
# The city kralendijk with ID: 3513563 is being processed
# umzimvubu missing field/result, keep going!
# The city narsaq with ID: 3421719 is being processed
# anifion missing field/result, keep going!
# The city tabou with ID: 2281120 is being processed
# The city rio verde de mato grosso with ID: 3451051 is being processed
# warqla missing field/result, keep going!
# The city mansa with ID: 1263622 is being processed
# The city hambantota with ID: 1244926 is being processed
# The city wentzville with ID: 4414001 is being processed
# The city fostoria with ID: 5154905 is being processed
# The city itoman with ID: 1861280 is being processed
# The city yichang with ID: 1786764 is being processed
# The city dong hoi with ID: 1582886 is being processed
# The city hobyo with ID: 57000 is being processed
# The city sohag with ID: 347796 is being processed
# The city panguna with ID: 2088659 is being processed
# The city anaconda with ID: 5637146 is being processed
# tarudant missing field/result, keep going!
# mentok missing field/result, keep going!
# The city mnogovershinnyy with ID: 2019935 is being processed
# The city mercedes with ID: 3430708 is being processed
# The city kondinskoye with ID: 1502697 is being processed
# andevoranto missing field/result, keep going!
# The city roald with ID: 3141667 is being processed
# The city banepa with ID: 1283679 is being processed
# The city vidim with ID: 2013406 is being processed
# The city sobolevo with ID: 525426 is being processed
# The city milkovo with ID: 2123278 is being processed
# The city kasongo-lunda with ID: 2315026 is being processed
# The city bondo with ID: 218253 is being processed
# The city kutum with ID: 371745 is being processed
# The city marzuq with ID: 72181 is being processed
# The city akhisar with ID: 324698 is being processed
# The city osoyoos with ID: 6094665 is being processed
# The city noumea with ID: 2139521 is being processed
# The city aleksandrov gay with ID: 583345 is being processed
# The city teknaf with ID: 1185095 is being processed
# The city hami with ID: 1529484 is being processed
# The city vardo with ID: 777019 is being processed
# The city hohhot with ID: 2036892 is being processed
# The city matamoros with ID: 3996426 is being processed
# The city sokoni with ID: 149812 is being processed
# The city karoi with ID: 889191 is being processed
# buqayq missing field/result, keep going!
# The city somerset with ID: 5104759 is being processed
# The city doha with ID: 290030 is being processed
# The city hastings with ID: 2647356 is being processed
# The city marrakesh with ID: 2542997 is being processed
# The city iquitos with ID: 3696183 is being processed
# The city kota bahru with ID: 1736376 is being processed
# The city shelburne with ID: 6145890 is being processed
# The city liberty with ID: 4205615 is being processed
# The city mount darwin with ID: 885800 is being processed
# The city ibra with ID: 287832 is being processed
# The city guerrero negro with ID: 4021858 is being processed
# The city esperance with ID: 2071860 is being processed
# The city high level with ID: 5975004 is being processed
# The city hualmay with ID: 3939761 is being processed
# The city port macquarie with ID: 2152659 is being processed
# The city broome with ID: 5110365 is being processed
# The city ulagan with ID: 1488048 is being processed
# The city yerbogachen with ID: 2012956 is being processed
# The city pisco with ID: 3932145 is being processed
# The city amargosa with ID: 3472370 is being processed
# The city quatre cocos with ID: 1106643 is being processed
# The city valle de allende with ID: 3980627 is being processed
# The city bawku with ID: 2303287 is being processed
# The city xuddur with ID: 49747 is being processed
# The city aguie with ID: 2448024 is being processed
# The city eyl with ID: 60019 is being processed
# The city athabasca with ID: 5887916 is being processed
# The city pacifica with ID: 5380420 is being processed
# The city whitehorse with ID: 6180550 is being processed
# The city henties bay with ID: 3356832 is being processed
# The city dalbandin with ID: 1180729 is being processed
# The city camopi with ID: 3382226 is being processed
# The city buckingham with ID: 2654410 is being processed
# The city akyab with ID: 1295765 is being processed
# The city los llanos de aridane with ID: 2514651 is being processed
# The city samarai with ID: 2132606 is being processed
# saleaula missing field/result, keep going!
# The city mandalgovi with ID: 2030065 is being processed
# The city sarangarh with ID: 1257242 is being processed
# galgani missing field/result, keep going!
# The city moindou with ID: 2140466 is being processed
# The city sterling with ID: 4787534 is being processed
# The city neiafu with ID: 4032420 is being processed
# The city bonavista with ID: 5905393 is being processed
# The city mehamn with ID: 778707 is being processed
# The city astana with ID: 1526273 is being processed
# The city dera bugti with ID: 1180295 is being processed
# The city usak with ID: 298298 is being processed
# The city biu with ID: 2346995 is being processed
# The city daru with ID: 2098329 is being processed
# The city bure with ID: 341397 is being processed
# The city asau with ID: 686090 is being processed
# The city kavieng with ID: 2094342 is being processed
# The city rawson with ID: 3839307 is being processed
# The city namatanai with ID: 2090021 is being processed
# The city lubao with ID: 1705441 is being processed
# The city wuxue with ID: 1790894 is being processed
# The city paita with ID: 3694112 is being processed
# The city tungor with ID: 2120400 is being processed
# The city bantou with ID: 1796663 is being processed
# The city balaipungut with ID: 1650600 is being processed
# The city kristinehamn with ID: 2699282 is being processed
# The city arlit with ID: 2447513 is being processed
# The city japura with ID: 1642773 is being processed
# The city pangnirtung with ID: 6096551 is being processed
# The city port blair with ID: 1259385 is being processed
# The city neryungri with ID: 2019309 is being processed
# bur gabo missing field/result, keep going!
# The city popondetta with ID: 2088163 is being processed
# The city azul with ID: 3436199 is being processed
# The city bellefontaine with ID: 5146965 is being processed
# The city surt with ID: 2210554 is being processed
# The city takoradi with ID: 2294915 is being processed
# The city castleford with ID: 2653584 is being processed
# The city san antonio with ID: 4726206 is being processed
# The city kiunga with ID: 2093846 is being processed
# sorvag missing field/result, keep going!
# The city cururupu with ID: 3401148 is being processed
# The city teguldet with ID: 1489822 is being processed
# The city tres arroyos with ID: 3833859 is being processed
# The city saint cloud with ID: 5044407 is being processed
# The city srandakan with ID: 1626493 is being processed
# The city reforma with ID: 3520406 is being processed
# The city axim with ID: 2303611 is being processed
# The city ulladulla with ID: 2145554 is being processed
# The city piterka with ID: 509269 is being processed
# The city kyabram with ID: 2160910 is being processed
# The city pata with ID: 1694477 is being processed
# The city abha with ID: 110690 is being processed
# The city avanigadda with ID: 1278122 is being processed

# %%
#craeate df

cities_comp = {
    "City": ciudad, 
    "Lat" : lat, 
    "Lng" : lon, 
    "Max Temp" : max_temp,
    "Humidity" : humidity,
    "Cloudiness" : cloudiness,
    "Wind Speed" : wind_speed,
    "Country" : country,
    "Date" : date 
}

city_data = pd.DataFrame(cities_comp)

#drop rows with no values, in the case
city_data = city_data.dropna()

#len(city_data)

city_data.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Xining  36.6167  101.7667     42.46        51          10        4.61
# 1  Bridlington  54.0831   -0.1919     34.00        68          95        5.01
# 2        Kidal  18.4411    1.4078     68.40        20          54       10.02
# 3        Pevek  69.7008  170.3133    -18.36        72           0        1.61
# 4      Rikitea -23.1203 -134.9692     78.44        79           2       14.25
#
#   Country        Date
# 0      CN  1613021127
# 1      GB  1613021128
# 2      ML  1613021128
# 3      RU  1613021128
# 4      PF  1613021128

# %%
#exporting df to csv

city_data.to_csv("city_data.csv", index=False, header=True)

# %% [markdown]
# "Max Temperature (F) vs. Latitude"

# %%
#scatter plot "Max Temperature (F) vs. Latitude"

plt.scatter(city_data["Lat"], city_data["Max Temp"], marker="o")

#graph properties
plt.title("Max Temperature vs Latitude in Cities")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

#save the plot
plt.savefig("Max Temperature_vs_latitude.png")

# %% [markdown]
# Observations "Max Temperature (F) vs. Latitude"
#
# 1.- As the graph shows, the closer you are to latitude 0, that is, closer to the equator, the max temperature tends to be higher.
# 2.- As the graph shows, the closer to high latitudes, the max temperature tends to be lower.
# 3.- The random sample indicates that there are more cities in higher latitudes than in lower latitudes.

# %% [markdown]
# "Humidity (%) vs. Latitude"

# %%
#scatter plot "Humidity (%) vs. Latitude"

plt.scatter(city_data["Lat"], city_data["Humidity"], marker="o")

#graph properties
plt.title("Humidity vs Latitude in Cities")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

#save the plot
plt.savefig("Humidity_vs_latitude.png")

# %% [markdown]
# Observations "Humidity (%) vs. Latitude"
#
# 1.- It is noted that a large part of the cities chosen for the analysis have a humidity close to 80% regardless of the latitude
# at which they are located.
# 2.- It seems that there is no direct relationship between the humidity of the cities and the latitude in which they are.

# %% [markdown]
# "Cloudiness vs. Latitude"

# %%
#scatter plot "Cloudiness vs. Latitude"

plt.scatter(city_data["Lat"], city_data["Cloudiness"], marker="o")

#graph properties
plt.title("Cloudiness vs Latitude in Cities")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

#save the plot
plt.savefig("Cloudiness_vs_latitude.png")

# %% [markdown]
# Observations "Cloudiness (%) vs. Latitude"
#
# 1.- It is noted that the Cloudiness in the selected cities is diverse throughout all latitudes.
#
# 2.- It seems that there is no direct relationship between the Cloudiness of the cities and the latitude in which they are.

# %% [markdown]
# "Wind Speed vs. Latitude"

# %%
#scatter plot "Wind Speed vs. Latitude"

plt.scatter(city_data["Lat"], city_data["Wind Speed"], marker="o")

#graph properties
plt.title("Wind Speed vs Latitude in Cities")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

#save the plot
plt.savefig("WindSpeed_vs_latitude.png")

# %% [markdown]
# Observations "Wind Speed (%) vs. Latitude"
#
# 1.- The graph shows that the selected cities have a wind speed in the range of 0 to 15 regardless of the latitude in which
# they are located.
# 2.- It seems that there is no direct relationship between the wind speed of the cities and the latitude in which they are.

# %%
#create some plots dividing the cities located in Northern Hemisphere and Southern Hemisphere

#creating a dataframe for each Hemisphere

North_cities = city_data.loc[(city_data["Lat"]>=0),:]
South_cities = city_data.loc[(city_data["Lat"]<0),:]

# %% [markdown]
# Northern Hemisphere - Max Temperature (F) vs. Latitude

# %%
#plot Northern Hemisphere - Max Temperature (F) vs. Latitude

plt.scatter(North_cities["Lat"], North_cities["Max Temp"], marker="o")

#graph properties
plt.title( "Northern Hemisphere - Max Temp vs Latitude in Cities")
plt.ylabel("Max Temp (F)")
plt.xlabel("Latitude")
plt.grid(True)

#linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(North_cities["Lat"], North_cities["Max Temp"])

regress_values = (North_cities["Lat"]) * slope + intercept

#print(regress_values)
line_eq = "y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))
print(line_eq)

plt.plot((North_cities["Lat"]), regress_values, color="red")
plt.annotate(line_eq, (0, -20), fontsize=15, color="red")

correlation = stats.pearsonr(North_cities["Lat"], North_cities["Max Temp"])
print(f"The correlation between both factors is {round(correlation[0],2)}")

plt.savefig("Northern Hemisphere - Max Temperature_vs_latitude.png")

plt.show()
# Out:
# y = -1.45X + 93.81
# The correlation between both factors is -0.89

# %% [markdown]
# Southern Hemisphere - Max Temperature (F) vs. Latitude

# %%
#plot Southern Hemisphere - Max Temperature (F) vs. Latitude

plt.figure()
plt.scatter(South_cities["Lat"], South_cities["Max Temp"], marker="o")

#graph properties
plt.title( "Southern Hemisphere - Max Temp vs Latitude in Cities")
plt.ylabel("Max Temp (F)")
plt.xlabel("Latitude")
plt.grid(True)

#linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(South_cities["Lat"], South_cities["Max Temp"])

regress_values = (South_cities["Lat"]) * slope + intercept

#print(regress_values)
line_eq = "y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))
print(line_eq)

plt.plot((South_cities["Lat"]), regress_values, color="red")
plt.annotate(line_eq, (-40, 50), fontsize=15, color="red")

correlation = stats.pearsonr(South_cities["Lat"], South_cities["Max Temp"])
print(f"The correlation between both factors is {round(correlation[0],2)}")

plt.savefig("Southern Hemisphere - Max Temperature_vs_latitude.png")

plt.show()
# Out:
# y = 0.3X + 80.81
# The correlation between both factors is 0.4

# %% [markdown]
# Observations:
#
# 1.- In the graph of the northern hemisphere, a strong negative correlation is observed, that is, the higher the latitude, the lower
# the maximum temperature and in the graph of the southern hemisphere, the correlation is moderate positive, the higher the latitude,
# the higher the maximum temperature.

# %% [markdown]
# Northern Hemisphere - Humidity vs. Latitude

# %%
#plot Northern Hemisphere - Humidity vs. Latitude

plt.scatter(North_cities["Lat"], North_cities["Humidity"], marker="o")

#graph properties
plt.title( "Northern Hemisphere - Humidity vs Latitude in Cities")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

#linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(North_cities["Lat"], North_cities["Humidity"])

regress_values = (North_cities["Lat"]) * slope + intercept

#print(regress_values)
line_eq = "y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))
print(line_eq)

plt.plot((North_cities["Lat"]), regress_values, color="red")
plt.annotate(line_eq, (40, 15), fontsize=15, color="red")

correlation = stats.pearsonr(North_cities["Lat"], North_cities["Humidity"])
print(f"The correlation between both factors is {round(correlation[0],2)}")

plt.savefig("Northern Hemisphere - Humidity_vs_latitude.png")

plt.show()
# Out:
# y = 0.36X + 56.93
# The correlation between both factors is 0.35

# %% [markdown]
# Southern Hemisphere - Humidity vs. Latitude

# %%
#plot Southern Hemisphere - Humidity vs. Latitude

plt.figure()
plt.scatter(South_cities["Lat"], South_cities["Humidity"], marker="o")

#graph properties
plt.title( "Southern Hemisphere - Humidity vs Latitude in Cities")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

#linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(South_cities["Lat"], South_cities["Humidity"])

regress_values = (South_cities["Lat"]) * slope + intercept

#print(regress_values)
line_eq = "y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))
print(line_eq)

plt.plot((South_cities["Lat"]), regress_values, color="red")
plt.annotate(line_eq, (-30, 45), fontsize=15, color="red")

correlation = stats.pearsonr(South_cities["Lat"], South_cities["Humidity"])
print(f"The correlation between both factors is {round(correlation[0],2)}")

plt.savefig("Southern Hemisphere - Humidity_vs_latitude.png")

plt.show()
# Out:
# y = 0.34X + 83.22
# The correlation between both factors is 0.25

# %% [markdown]
# Observations:
#
# 1.- The graphs of both hemispheres, the north and the south show a weak positive correlation, as latitude increases, a slight
# increase in humidity in cities

# %% [markdown]
# Northern Hemisphere - Cloudiness vs. Latitude

# %%
#plot Northern Hemisphere - Cloudiness vs. Latitude

plt.scatter(North_cities["Lat"], North_cities["Cloudiness"], marker="o")

#graph properties
plt.title( "Northern Hemisphere - Cloudiness vs Latitude in Cities")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

#linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(North_cities["Lat"], North_cities["Cloudiness"])

regress_values = (North_cities["Lat"]) * slope + intercept

#print(regress_values)
line_eq = "y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))
print(line_eq)

plt.plot((North_cities["Lat"]), regress_values, color="red")
plt.annotate(line_eq, (20, 30), fontsize=15, color="red")

correlation = stats.pearsonr(North_cities["Lat"], North_cities["Cloudiness"])
print(f"The correlation between both factors is {round(correlation[0],2)}")

plt.savefig("Northern Hemisphere - Cloudiness_vs_latitude.png")

plt.show()
# Out:
# y = 0.2X + 39.9
# The correlation between both factors is 0.11

# %% [markdown]
# Southern Hemisphere - Cloudiness vs. Latitude

# %%
#plot Southern Hemisphere - Cloudiness vs. Latitude

plt.figure()
plt.scatter(South_cities["Lat"], South_cities["Cloudiness"], marker="o")

#graph properties
plt.title( "Southern Hemisphere - Cloudiness vs Latitude in Cities")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

#linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(South_cities["Lat"], South_cities["Cloudiness"])

regress_values = (South_cities["Lat"]) * slope + intercept

#print(regress_values)
line_eq = "y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))
print(line_eq)

plt.plot((South_cities["Lat"]), regress_values, color="red")
plt.annotate(line_eq, (-55, 60), fontsize=15, color="red")

correlation = stats.pearsonr(South_cities["Lat"], South_cities["Cloudiness"])
print(f"The correlation between both factors is {round(correlation[0],2)}")

plt.savefig("Southern Hemisphere - Cloudiness_vs_latitude.png")

plt.show()
# Out:
# y = 0.73X + 80.02
# The correlation between both factors is 0.27

# %% [markdown]
# Observations:
#
# 1.- The graph of the northern hemisphere shows that the Cloudiness increases slightly as the latitude increases, weak correlation
# 2.- While the graph of the southern hemisphere shows that the Cloudiness increase faster as the latitude increases, also weak correlation.

# %% [markdown]
# Northern Hemisphere - Wind Speed vs. Latitude

# %%
#plot Northern Hemisphere - Wind Speed vs. Latitude

plt.scatter(North_cities["Lat"], North_cities["Wind Speed"], marker="o")

#graph properties
plt.title( "Northern Hemisphere - Wind Speed vs Latitude in Cities")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

#linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(North_cities["Lat"], North_cities["Wind Speed"])

regress_values = (North_cities["Lat"]) * slope + intercept

#print(regress_values)
line_eq = "y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))
print(line_eq)

plt.plot((North_cities["Lat"]), regress_values, color="red")
plt.annotate(line_eq, (0, 30), fontsize=15, color="red")

correlation = stats.pearsonr(North_cities["Lat"], North_cities["Wind Speed"])
print(f"The correlation between both factors is {round(correlation[0],2)}")

plt.savefig("Northern Hemisphere - Wind Speed_vs_latitude.png")

plt.show()
# Out:
# y = 0.03X + 6.84
# The correlation between both factors is 0.09

# %% [markdown]
# Southern Hemisphere - Wind Speed vs. Latitude

# %%
#plot Southern Hemisphere - Wind Speed vs. Latitude

plt.figure()
plt.scatter(South_cities["Lat"], South_cities["Wind Speed"], marker="o")

#graph properties
plt.title( "Southern Hemisphere - Wind Speed vs Latitude in Cities")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

#linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(South_cities["Lat"], South_cities["Wind Speed"])

regress_values = (South_cities["Lat"]) * slope + intercept

#print(regress_values)
line_eq = "y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))
print(line_eq)

plt.plot((South_cities["Lat"]), regress_values, color="red")
plt.annotate(line_eq, (-40, 30), fontsize=15, color="red")

correlation = stats.pearsonr(South_cities["Lat"], South_cities["Wind Speed"])
print(f"The correlation between both factors is {round(correlation[0],2)}")

plt.savefig("Southern Hemisphere - Wind Speed_vs_latitude.png")

plt.show()
# Out:
# y = -0.12X + 5.06
# The correlation between both factors is -0.28

# %% [markdown]
# Observations:
#
# 1.- Both graphs of the northern and southern hemispheres that relate wind speed versus latitude show that there is no
# correlation between the two factors.
